# %% [markdown]
# <a href="https://colab.research.google.com/github/stephe-hu/datacsi_1_loading/blob/main/hha507Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Acquisition

# %%
import pandas as pd

# %% [markdown]
# ##CSV Files

# %%
dataset1 = pd.read_csv('gun_violence_children_deaths.csv')
dataset1.head(10)
# Out:
#    Incident ID    Incident Date           State City Or County  \
# 0      2696508  August 31, 2023  North Carolina    Statesville
# 1      2694938  August 30, 2023         Indiana           Gary
# 2      2695116  August 30, 2023         Georgia        Atlanta
# 3      2694681  August 29, 2023         Florida        Orlando
# 4      2693825  August 28, 2023           Texas          Allen
# 5      2693375  August 27, 2023       Tennessee       Rockwood
# 6      2692267  August 27, 2023         Florida     Lake Wales
# 7      2691312  August 26, 2023            Ohio          Akron
# 8      2690239  August 24, 2023            Ohio      Hartville
# 9      2687183  August 21, 2023           Texas        Lubbock
#
#                       Address  Victims Killed  Victims Injured  \
# 0  100 block of Fort Dobbs Rd               1                0
# 1   2400 block of Fillmore St               1                0
# 2      2909 Campbellton Rd SW               1                2
# ...

# %% [markdown]
# *   Incident ID - code to identify the case of victim death as a result of gun violence
# *   Incident Date - date when the incident occurred
# *   State - state where the incident occurred
# *   City or County - city or county where the incident occurred
# *   Address - address where the incident occurred
# *   Victims Killed - number of children that were killed
# *   Victims Injured - number of children that were injured
# *   Suspects Killed - number of suspects that were killed
# *   Suspects Injured - number of suspects that were injured
# *   Suspects Arrested - number of suspects that were arrested
# *   Operations - action taken in response to the incident

# %%
dataset2 = pd.read_csv('mass_shooting_2022.csv')
dataset2.head(10)
# Out:
#    Incident ID      Incident Date                 State City Or County  \
# 0      2492253  December 31, 2022               Alabama         Mobile
# 1      2491656  December 31, 2022               Arizona        Phoenix
# 2      2491054  December 30, 2022             Tennessee        Memphis
# 3      2490925  December 30, 2022                 Texas         Humble
# 4      2489614  December 28, 2022              New York          Bronx
# 5      2490150  December 28, 2022                 Texas         Dallas
# 6      2488952  December 27, 2022  District of Columbia     Washington
# 7      2489345  December 27, 2022                  Ohio       Columbus
# 8      2489124  December 27, 2022            California         Eureka
# 9      2488209  December 26, 2022             Louisiana    New Orleans
#
#                              Address  Victims Killed  Victims Injured  \
# 0            200 block of Dauphin St               1                7
# ...

# %% [markdown]
# *   Incident ID - code to identify the case mass shooting
# *   Incident Date - date when the incident occurred
# *   State - state where the incident occurred
# *   City or County - city or county where the incident occurred
# *   Address - address where the incident occurred
# *   Victims Killed - number of children that were killed
# *   Victims Injured - number of children that were injured
# *   Suspects Killed - number of suspects that were killed
# *   Suspects Injured - number of suspects that were injured
# *   Suspects Arrested - number of suspects that were arrested
# *   Operations - action taken in response to the incident

# %% [markdown]
# ##XLSX Files

# %%
dataset3 = pd.read_excel('covid_deaths.xlsx')
dataset3.head(10)
# Out:
#   Data as of          Age group  COVID-19 Deaths Indicator     Sex  \
# 0 2023-06-28          0-4 years              776       Age     All
# 1 2023-06-28         5-18 years             1071       Age     All
# 2 2023-06-28        19-44 years            44690       Age     All
# 3 2023-06-28        45-64 years           230021       Age     All
# 4 2023-06-28        65-74 years           254951       Age     All
# 5 2023-06-28  75 years and over           604543       Age     All
# 6 2023-06-28           All ages          1136052       Age     All
# 7 2023-06-28          0-4 years              357       Sex  Female
# 8 2023-06-28          0-4 years              419       Sex    Male
# 9 2023-06-28         5-18 years              483       Sex  Female
#
#   Race or Hispanic Origin Group Start Week   End Week
# 0                           All 2020-01-04 2023-06-24
# 1                           All 2020-01-04 2023-06-24
# 2                           All 2020-01-04 2023-06-24
# ...

# %% [markdown]
# *   Date as of - date when the data was last updated
# *   Age group - record of different age groups for covid-19 deaths
# *   COVID-19 Deaths - number of deaths related to covid-19 for each age agroup
# *   Indicator - specific characteristic related to each reported death
# *   Sex - sex group of each reported death
# *   Race or Hispanic Origin Group - racial group for each reported death
# *   Start Week - first week of data collection
# *   End Week - last week of data collection

# %%
dataset4 = pd.read_excel('ca-oshpd-cancer-surgeries-gachospitals-20132021.xlsx')
dataset4.head(10)
# Out:
#    Year County   Hospital  OSHPDID    Surgery  # of Cases (ICD 9)  \
# 0  2013    NaN  Statewide      NaN      Colon              7128.0
# 1  2013    NaN  Statewide      NaN    Bladder               892.0
# 2  2013    NaN  Statewide      NaN     Rectum              2128.0
# 3  2013    NaN  Statewide      NaN     Breast             25829.0
# 4  2013    NaN  Statewide      NaN      Brain              2719.0
# 5  2013    NaN  Statewide      NaN   Pancreas               819.0
# 6  2013    NaN  Statewide      NaN       Lung              3145.0
# 7  2013    NaN  Statewide      NaN      Liver              1159.0
# 8  2013    NaN  Statewide      NaN  Esophagus               337.0
# 9  2013    NaN  Statewide      NaN    Stomach              1010.0
#
#    # of Cases (ICD 10)  LONGITUDE  LATITUDE
# 0                  NaN        NaN       NaN
# 1                  NaN        NaN       NaN
# 2                  NaN        NaN       NaN
# 3                  NaN        NaN       NaN
# ...

# %% [markdown]
# *   Year - year where data is collected
# *   County - county in California where surgery is performed
# *   Hospital - name of the hospital where surgery is performed
# *   OSHPHID - unique identifier assigned to each hospital
# *   Surgery - type of cancer surgery that is performed
# *   Num of Cases (ICD 9) - number of cancer surgeries associated with ICD 9
# *   Num of Cases (ICD 10) - number of cancer surgeries associated with ICD 10
# *   Longitude - longitudinal coordinate of the hospital
# *   Latitude - latitudinal coordinate of the hospital

# %%
dataset5 = pd.read_excel('NCHS_-_Age-adjusted_Death_Rates_for_Selected_Major_Causes_of_Death.xlsx')
dataset5.head(10)
# Out:
#    Year          Cause  Age Adjusted Death Rate
# 0  1900  Heart Disease                    265.4
# 1  1901  Heart Disease                    272.6
# 2  1902  Heart Disease                    285.2
# 3  1903  Heart Disease                    304.5
# 4  1904  Heart Disease                    331.5
# 5  1905  Heart Disease                    327.8
# 6  1906  Heart Disease                    325.5
# 7  1907  Heart Disease                    356.5
# 8  1908  Heart Disease                    328.6
# 9  1909  Heart Disease                    329.2

# %% [markdown]
# *   Year - year where data is collected from
# *   Cause - leading cause of death that year
# *   Age Adjusted Death Rate - mortality rate of the cause of death for that year accounting for differences in age distributions

# %% [markdown]
# ##JSON Files

# %%
dataset6 = pd.read_json('https://data.cms.gov/data-api/v1/dataset/be64fce3-e835-4589-b46b-024198e524a6/data')
dataset6.head(10)
# Out:
#              Brnd_Name                       Gnrc_Name  Tot_Mftr  \
# 0   8hr Arthritis Pain                   Acetaminophen         1
# 1   8hr Arthritis Pain                   Acetaminophen         1
# 2                A & D                Vitamins A And D         1
# 3                A & D                Vitamins A And D         1
# 4              A And D  Vits A And D/White Pet/Lanolin         1
# 5              A And D  Vits A And D/White Pet/Lanolin         1
# 6  A And D Diaper Rash  Dimethic/Zinc Ox/Vits A,D/Aloe         1
# 7  A And D Diaper Rash  Dimethic/Zinc Ox/Vits A,D/Aloe         1
# 8          A-Hydrocort    Hydrocortisone Sod Succinate         1
# 9          A-Hydrocort    Hydrocortisone Sod Succinate         1
#
#          Mftr_Name Tot_Spndng_2017 Tot_Dsg_Unts_2017 Tot_Clms_2017  \
# 0          Overall
# 1            Topco
# 2          Overall
# 3  Schering-Plough
# 4          Overall          406.33            3502.5            47
# ...

# %% [markdown]
# *   Brnd_Name - brand name of the drug
# *   Gnrc_Name - generic name of the drug
#
# *   Tot_Mftr - total number of manufacturer that makes the product
# *   Mftr_Name - name of the manufacturer
#
#
# *   Tot_Spnding- total spending on the drug the year
# *   Tot_Dsg_Unts - total dosage unit of the drug sold in the year
#
# *   Tot_Clms - total number of claims for reimbursement in the year
# *   Avg_Spnd_Per_Dsg_Unt_Wghtd - average spending per dosage unit in the year
#
# *   Avg_Spnd_Per_Clm - average spending per claim in the year
# *   Outlier_Flag - outlier data in the year
#
# *  Chg_Avg_Spnd_Per_Dsg_Unt_20_21 - change in average spending per dosage unit from 2020 to 2021.
# *   CAGR_Avg_Spnd_Per_Dsg_Unt_17_21 - Compound Annual Growth Rate (CAGR) of average spending per dosage unit from 2017 to 2021

# %%
dataset7 = pd.read_json('https://data.cms.gov/data-api/v1/dataset/c37ebe6d-f54f-4d7d-861f-fefe345554e6/data')
dataset7.head(10)
# Out:
#    Year   Geo_Lvl Geo_Cd  Geo_Desc Plan_Type Tot_Opioid_Clms   Tot_Clms  \
# 0  2021  National         National       All        21654225  686625295
# 1  2021  National         National       FFS         5084859  180712324
# 2  2021  National         National        MC        16569366  505912971
# 3  2021     State     01   Alabama       All          175237    7525456
# 4  2021     State     01   Alabama       FFS          175237    7525456
# 5  2021     State     01   Alabama        MC               0          0
# 6  2021     State     02    Alaska       All           58330    1436383
# 7  2021     State     02    Alaska       FFS           58330    1436383
# 8  2021     State     02    Alaska        MC               0          0
# 9  2021     State     04   Arizona       All          512306   14333371
#
#   Opioid_Prscrbng_Rate Opioid_Prscrbng_Rate_5Y_Chg  \
# 0                 3.15                       -2.23
# 1                 2.81                       -2.48
# ...

# %% [markdown]
# *   Year - year where the data is reported
# *   Geo_Lvl - geographical level at which the data is reported
# *   Geo_Cd - codes that identify specific geographical areas
# *   Geo_Desc - description of geographical areas
# *   Plan_Type - healthcare plan
#
# *   Tot_Opiod_Clms - total claims for opioid prescriptions
# *   Tot_Clms - total claims
#
# *   Opioid_Prscrbng_Rate - rate at which opioid is prescribed
# *   Opioid_Prscrbng_Rate_5Y_Chg - percent change for opioid prescription rate over a 5-year period
#
# *   Opioid_Prscrbng_Rate_1Y_Chg - percent change for opioid prescription rate over a 1-year period
# *   LA_Tot_Opioid_Clms - total claims for opioid prescriptions in Los Angeles (LA)
#
# *   LA_Opioid_Prscrbng_Rate - rate at which opioid is prescribed in LA
# *   LA_Opioid_Prscrbng_Rate_5Y_Chg - percent change for opioid prescription rate over a 5-year period in LA
#
# *   LA_Opioid_Prscrbng_Rate_1Y_Chg - percent change for opioid prescription rate over a 1-year period in LA

# %% [markdown]
# *   Name of Initiative - name of the program
# *   Organization Name - name of the organization responsible for hte program
#
# *   Location Name - location where the initiative is provided by the organization
# *   Location 1 - additional information about location
#
# *   Street Address Line 1 - first line of the street address for the location
# *   Street Address Line 2 - second line of the street address for the location
#
# *   City - city where the initiative is provided
# *   State - state where the initiative is provided
#
# *   ZIP Code - postal code for identifying the location
# *   Telephone Number - contact information about the facility
#
# *   NPI - National Provider Number to identify the provider within the program
# *   Category - the type of services provided
#
# *   Unique ID - unique identifier for each record
