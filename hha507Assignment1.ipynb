# %% [markdown]
# <a href="https://colab.research.google.com/github/stephe-hu/datacsi_1_loading/blob/main/hha507Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Acquisition

# %%
import pandas as pd

# %% [markdown]
# ##CSV Files

# %%
dataset1 = pd.read_csv("https://raw.githubusercontent.com/hantswilliams/HHA_504_2023/main/WK1/data/113243405_StonyBrookEasternLongIslandHospital_standardcharges.csv")
dataset1.head(10)
# Out:
#     Code                                        Description        Type  \
# 0  10060          SIMPLE OR SINGLE DRAINAGE OF SKIN ABSCESS  Outpatient
# 1  10060          SIMPLE OR SINGLE DRAINAGE OF SKIN ABSCESS  Outpatient
# 2  10080                SIMPLE DRAINAGE OF CYST OF TAILBONE  Outpatient
# 3  10080                SIMPLE DRAINAGE OF CYST OF TAILBONE  Outpatient
# 4  10120  REMOVAL OF FOREIGN BODY FROM TISSUE, ACCESSED ...  Outpatient
# 5  10120  REMOVAL OF FOREIGN BODY FROM TISSUE, ACCESSED ...  Outpatient
# 6  10140            DRAINAGE OF BLOOD OR FLUID ACCUMULATION  Outpatient
# 7  10140            DRAINAGE OF BLOOD OR FLUID ACCUMULATION  Outpatient
# 8  11042     REMOVAL OF SKIN AND TISSUE, 20.0 SQ CM OR LESS  Outpatient
# 9  11042     REMOVAL OF SKIN AND TISSUE, 20.0 SQ CM OR LESS  Outpatient
#
#   Package/Line_Level  Gross charge  Discounted cash price  \
# 0               Line        575.75                 575.75
# ...

# %%
dataset2 = pd.read_csv("https://raw.githubusercontent.com/hantswilliams/HHA_504_2023/main/WK1/data/113243405_StonyBrookUniversityHospital_standardcharges.csv")
dataset2.head(10)
# Out:
#     Code                                        Description        Type  \
# 0  10004  FINE NEEDLE ASPIRATION BIOPSY, EACH ADDITIONAL...  Outpatient
# 1  10005  FINE NEEDLE ASPIRATION BIOPSY USING ULTRASOUND...  Outpatient
# 2  10005  FINE NEEDLE ASPIRATION BIOPSY USING ULTRASOUND...  Outpatient
# 3  10006  FINE NEEDLE ASPIRATION BIOPSY USING ULTRASOUND...  Outpatient
# 4  10009  FINE NEEDLE ASPIRATION BIOPSY OF GROWTH USING ...  Outpatient
# 5  10009  FINE NEEDLE ASPIRATION BIOPSY OF GROWTH USING ...  Outpatient
# 6  10010  FINE NEEDLE ASPIRATION BIOPSY OF GROWTH USING ...  Outpatient
# 7  10021        FINE NEEDLE ASPIRATION BIOPSY, FIRST GROWTH  Outpatient
# 8  10021        FINE NEEDLE ASPIRATION BIOPSY, FIRST GROWTH  Outpatient
# 9  10030  DRAINAGE OF FLUID COLLECTION IN SOFT TISSUE US...  Outpatient
#
#   Package/Line_Level  Gross charge  Discounted cash price  \
# 0               Line        718.67                 718.67
# ...

# %% [markdown]
# ##XLSX Files

# %%
dataset3 = pd.read_excel('covid_deaths.xlsx')
dataset3.head(10)
# Out:
#   Data as of          Age group  COVID-19 Deaths Indicator     Sex  \
# 0 2023-06-28          0-4 years              776       Age     All
# 1 2023-06-28         5-18 years             1071       Age     All
# 2 2023-06-28        19-44 years            44690       Age     All
# 3 2023-06-28        45-64 years           230021       Age     All
# 4 2023-06-28        65-74 years           254951       Age     All
# 5 2023-06-28  75 years and over           604543       Age     All
# 6 2023-06-28           All ages          1136052       Age     All
# 7 2023-06-28          0-4 years              357       Sex  Female
# 8 2023-06-28          0-4 years              419       Sex    Male
# 9 2023-06-28         5-18 years              483       Sex  Female
#
#   Race or Hispanic Origin Group Start Week   End Week
# 0                           All 2020-01-04 2023-06-24
# 1                           All 2020-01-04 2023-06-24
# 2                           All 2020-01-04 2023-06-24
# ...

# %%
dataset4 = pd.read_excel('ca-oshpd-cancer-surgeries-gachospitals-20132021.xlsx')
dataset4.head(10)
# Out:
#    Year County   Hospital  OSHPDID    Surgery  # of Cases (ICD 9)  \
# 0  2013    NaN  Statewide      NaN      Colon              7128.0
# 1  2013    NaN  Statewide      NaN    Bladder               892.0
# 2  2013    NaN  Statewide      NaN     Rectum              2128.0
# 3  2013    NaN  Statewide      NaN     Breast             25829.0
# 4  2013    NaN  Statewide      NaN      Brain              2719.0
# 5  2013    NaN  Statewide      NaN   Pancreas               819.0
# 6  2013    NaN  Statewide      NaN       Lung              3145.0
# 7  2013    NaN  Statewide      NaN      Liver              1159.0
# 8  2013    NaN  Statewide      NaN  Esophagus               337.0
# 9  2013    NaN  Statewide      NaN    Stomach              1010.0
#
#    # of Cases (ICD 10)  LONGITUDE  LATITUDE
# 0                  NaN        NaN       NaN
# 1                  NaN        NaN       NaN
# 2                  NaN        NaN       NaN
# 3                  NaN        NaN       NaN
# ...

# %%
dataset5 = pd.read_excel('NCHS_-_Age-adjusted_Death_Rates_for_Selected_Major_Causes_of_Death.xlsx')
dataset5.head(10)
# Out:
#    Year          Cause  Age Adjusted Death Rate
# 0  1900  Heart Disease                    265.4
# 1  1901  Heart Disease                    272.6
# 2  1902  Heart Disease                    285.2
# 3  1903  Heart Disease                    304.5
# 4  1904  Heart Disease                    331.5
# 5  1905  Heart Disease                    327.8
# 6  1906  Heart Disease                    325.5
# 7  1907  Heart Disease                    356.5
# 8  1908  Heart Disease                    328.6
# 9  1909  Heart Disease                    329.2

# %% [markdown]
# ##JSON Files
